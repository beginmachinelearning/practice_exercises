# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
from scipy import stats
from scipy.stats import norm

# %%
data_train=pd.read_csv("data/Train.csv")
data_test=pd.read_csv("data/Test.csv")

# %%
labels_train=data_train['Item_Outlet_Sales']

# %%
data_train.shape, data_test.shape
# Out:
# ((8523, 12), (5681, 11))

# %%
all_data=data_train.append(data_test)

# %%
all_data.shape
# Out:
# (14204, 12)

# %%
all_data.iloc[8000:, :]
# Out:
#      Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales  \
# 8000          Low Fat           FDS55  150.0734          4454.2020
# 8001          Low Fat           FDT21  247.1092          4233.1564
# 8002          Low Fat           NCR38  253.5724          5033.4480
# 8003          Low Fat           FDJ22  190.6504          1342.2528
# 8004              reg           FDB57  220.5772          2446.1492
# 8005          Regular           FDR52  192.3846          1910.8460
# 8006          Low Fat           NCO41   96.7384          2167.8448
# 8007          Low Fat           FDG47  261.4252           262.3252
# 8008          Low Fat           FDB44  212.4586          2743.7618
# 8009          Low Fat           FDY14  263.0226          4229.1616
# 8010          Low Fat           NCN55  239.2538          3605.3070
# 8011          Regular           FDV48   77.4644          1414.1592
# 8012          Low Fat           FDA21  185.2924          3146.5708
# 8013          Low Fat           FDZ27   51.2350           848.8950
# 8014          Low Fat           FDW58  104.1622          1693.7952
# 8015          Regular           FDH45   41.6796           784.3124
# 8016          Low Fat           FDH38  115.2808           117.1808
# 8017          Low Fat           FDL43   76.3670           765.6700
# 8018          Regular           FDD38  100.3674          1833.6132
# 8019          Low Fat           FDV02  173.0106          3593.3226
# 8020          Low Fat           NCF31  152.8024          1214.4192
# 8021          Low Fat           NCN05  182.1950          2380.2350
# 8022          Regular           FDZ16  194.1478          5812.4340
# 8023          Low Fat           NCT18  181.5976          4165.2448
# 8024          Low Fat           NCP50   79.4618          1772.3596
# 8025          Low Fat           FDW13   50.5324           207.7296
# 8026          Low Fat           NCS53  159.9604          2218.4456
# 8027          Low Fat           DRG03  153.0998          4921.5936
# 8028          Low Fat           DRE60  227.8720          1584.6040
# 8029          Low Fat           FDK21  248.3408           751.0224
# ...               ...             ...       ...                ...
# 5651          Regular           FDD23  186.1898                NaN
# 5652          Low Fat           FDP32  126.7678                NaN
# 5653          Regular           FDO31   80.2960                NaN
# 5654          Low Fat           FDQ57  144.5760                NaN
# 5655          Regular           FDX32  143.6786                NaN
# 5656          Low Fat           FDC39  207.8296                NaN
# 5657          Low Fat           FDU55  261.3278                NaN
# 5658          Low Fat           FDL45  123.4704                NaN
# 5659          Low Fat           DRK37  188.8530                NaN
# 5660          Low Fat           FDK22  215.3850                NaN
# 5661          Low Fat           DRG37  155.7972                NaN
# 5662          Low Fat           FDK22  214.3850                NaN
# 5663          Low Fat           DRH36   72.8696                NaN
# 5664          Regular           DRC36  173.4054                NaN
# 5665          Low Fat           DRE03   46.0718                NaN
# 5666          Regular           FDF34  196.9084                NaN
# 5667          Low Fat           FDZ22   82.1250                NaN
# 5668          Low Fat           FDC44  115.1518                NaN
# 5669          Low Fat           FDN31  188.0530                NaN
# 5670          Regular           FDO03  229.4352                NaN
# 5671              reg           FDA01   59.5904                NaN
# 5672          Low Fat           NCH42  231.1010                NaN
# 5673          Low Fat           FDF46  116.0834                NaN
# 5674          Low Fat           DRL35   43.2770                NaN
# 5675          Regular           FDW46   63.4484                NaN
# 5676          Regular           FDB58  141.3154                NaN
# 5677          Regular           FDD47  169.1448                NaN
# 5678          Low Fat           NCO17  118.7440                NaN
# 5679          Regular           FDJ26  214.6218                NaN
# 5680          Regular           FDU37   79.7960                NaN
#
#                   Item_Type  Item_Visibility  Item_Weight  \
# 8000  Fruits and Vegetables         0.081329        7.020
# 8001            Snack Foods         0.020388        7.420
# 8002              Household         0.113518       17.250
# 8003            Snack Foods         0.052917       18.750
# 8004  Fruits and Vegetables         0.018911       20.250
# 8005           Frozen Foods         0.075981       12.650
# 8006     Health and Hygiene         0.018849       12.500
# 8007          Starchy Foods         0.116528       12.800
# 8008  Fruits and Vegetables         0.000000        6.655
# 8009                  Dairy         0.070040       10.300
# 8010                 Others         0.059827       14.600
# 8011           Baking Goods         0.051827        9.195
# 8012            Snack Foods         0.035954       13.650
# 8013                  Dairy         0.017183        7.935
# 8014            Snack Foods         0.007547       20.750
# 8015  Fruits and Vegetables         0.105831       15.100
# 8016                 Canned         0.018276          NaN
# 8017                   Meat         0.027064       10.100
# 8018                 Canned         0.000000          NaN
# 8019                  Dairy         0.060640       16.750
# 8020              Household         0.051847        9.130
# 8021     Health and Hygiene         0.014519        8.235
# 8022           Frozen Foods         0.159723       16.850
# 8023              Household         0.059117          NaN
# 8024                 Others         0.020556       17.350
# 8025                 Canned         0.171384          NaN
# 8026     Health and Hygiene         0.090286       14.500
# 8027                  Dairy         0.061987       14.500
# 8028            Soft Drinks         0.160236        9.395
# 8029            Snack Foods         0.010033        7.905
# ...                     ...              ...          ...
# 5651          Starchy Foods         0.048645        9.500
# 5652  Fruits and Vegetables         0.087847        6.650
# 5653  Fruits and Vegetables         0.028977        6.760
# 5654            Snack Foods         0.000000        7.275
# 5655  Fruits and Vegetables         0.099375          NaN
# 5656                  Dairy         0.158425          NaN
# 5657  Fruits and Vegetables         0.035911       16.200
# 5658            Snack Foods         0.037656       15.600
# 5659            Soft Drinks         0.044073        5.000
# 5660            Snack Foods         0.026065        9.800
# 5661            Soft Drinks         0.000000          NaN
# 5662            Snack Foods         0.026234        9.800
# 5663            Soft Drinks         0.033516       16.200
# 5664            Soft Drinks         0.045168       13.000
# 5665                  Dairy         0.024110          NaN
# 5666            Snack Foods         0.014019        9.300
# 5667            Snack Foods         0.045270        9.395
# 5668  Fruits and Vegetables         0.288892       15.600
# 5669  Fruits and Vegetables         0.072529          NaN
# 5670                   Meat         0.037092       10.395
# 5671                 Canned         0.054463       15.000
# 5672              Household         0.036594        6.860
# 5673            Snack Foods         0.094053        7.070
# 5674            Hard Drinks         0.030704       15.700
# 5675            Snack Foods         0.070411       13.000
# 5676            Snack Foods         0.013496       10.500
# 5677          Starchy Foods         0.142991        7.600
# 5678     Health and Hygiene         0.073529       10.000
# 5679                 Canned         0.000000       15.300
# 5680                 Canned         0.104720        9.500
#
#       Outlet_Establishment_Year Outlet_Identifier Outlet_Location_Type  \
# 8000                       2002            OUT045               Tier 2
# 8001                       2004            OUT035               Tier 2
# 8002                       1997            OUT046               Tier 1
# 8003                       2002            OUT045               Tier 2
# 8004                       2007            OUT017               Tier 2
# 8005                       1987            OUT013               Tier 3
# 8006                       1997            OUT046               Tier 1
# 8007                       1998            OUT010               Tier 3
# 8008                       2007            OUT017               Tier 2
# 8009                       1997            OUT046               Tier 1
# 8010                       2007            OUT017               Tier 2
# 8011                       2009            OUT018               Tier 3
# 8012                       2004            OUT035               Tier 2
# 8013                       1999            OUT049               Tier 1
# 8014                       1987            OUT013               Tier 3
# 8015                       1999            OUT049               Tier 1
# 8016                       1985            OUT019               Tier 1
# 8017                       1997            OUT046               Tier 1
# 8018                       1985            OUT027               Tier 3
# 8019                       1999            OUT049               Tier 1
# 8020                       1997            OUT046               Tier 1
# 8021                       2009            OUT018               Tier 3
# 8022                       1987            OUT013               Tier 3
# 8023                       1985            OUT027               Tier 3
# 8024                       2004            OUT035               Tier 2
# 8025                       1985            OUT019               Tier 1
# 8026                       2007            OUT017               Tier 2
# 8027                       1997            OUT046               Tier 1
# 8028                       2007            OUT017               Tier 2
# 8029                       2002            OUT045               Tier 2
# ...                         ...               ...                  ...
# 5651                       1987            OUT013               Tier 3
# 5652                       2002            OUT045               Tier 2
# 5653                       2004            OUT035               Tier 2
# 5654                       1987            OUT013               Tier 3
# 5655                       1985            OUT027               Tier 3
# 5656                       1985            OUT027               Tier 3
# 5657                       1997            OUT046               Tier 1
# 5658                       1987            OUT013               Tier 3
# 5659                       1999            OUT049               Tier 1
# 5660                       1987            OUT013               Tier 3
# 5661                       1985            OUT027               Tier 3
# 5662                       2007            OUT017               Tier 2
# 5663                       2009            OUT018               Tier 3
# 5664                       2009            OUT018               Tier 3
# 5665                       1985            OUT027               Tier 3
# 5666                       1997            OUT046               Tier 1
# 5667                       1997            OUT046               Tier 1
# 5668                       1998            OUT010               Tier 3
# 5669                       1985            OUT027               Tier 3
# 5670                       2007            OUT017               Tier 2
# 5671                       1999            OUT049               Tier 1
# 5672                       1999            OUT049               Tier 1
# 5673                       2009            OUT018               Tier 3
# 5674                       1997            OUT046               Tier 1
# 5675                       1999            OUT049               Tier 1
# 5676                       1997            OUT046               Tier 1
# 5677                       2009            OUT018               Tier 3
# 5678                       2002            OUT045               Tier 2
# 5679                       2007            OUT017               Tier 2
# 5680                       2002            OUT045               Tier 2
#
#      Outlet_Size        Outlet_Type
# 8000         NaN  Supermarket Type1
# 8001       Small  Supermarket Type1
# 8002       Small  Supermarket Type1
# 8003         NaN  Supermarket Type1
# 8004         NaN  Supermarket Type1
# 8005        High  Supermarket Type1
# 8006       Small  Supermarket Type1
# 8007         NaN      Grocery Store
# 8008         NaN  Supermarket Type1
# 8009       Small  Supermarket Type1
# 8010         NaN  Supermarket Type1
# 8011      Medium  Supermarket Type2
# 8012       Small  Supermarket Type1
# 8013      Medium  Supermarket Type1
# 8014        High  Supermarket Type1
# 8015      Medium  Supermarket Type1
# 8016       Small      Grocery Store
# 8017       Small  Supermarket Type1
# 8018      Medium  Supermarket Type3
# 8019      Medium  Supermarket Type1
# 8020       Small  Supermarket Type1
# 8021      Medium  Supermarket Type2
# 8022        High  Supermarket Type1
# 8023      Medium  Supermarket Type3
# 8024       Small  Supermarket Type1
# 8025       Small      Grocery Store
# 8026         NaN  Supermarket Type1
# 8027       Small  Supermarket Type1
# 8028         NaN  Supermarket Type1
# 8029         NaN  Supermarket Type1
# ...          ...                ...
# 5651        High  Supermarket Type1
# 5652         NaN  Supermarket Type1
# 5653       Small  Supermarket Type1
# 5654        High  Supermarket Type1
# 5655      Medium  Supermarket Type3
# 5656      Medium  Supermarket Type3
# 5657       Small  Supermarket Type1
# 5658        High  Supermarket Type1
# 5659      Medium  Supermarket Type1
# 5660        High  Supermarket Type1
# 5661      Medium  Supermarket Type3
# 5662         NaN  Supermarket Type1
# 5663      Medium  Supermarket Type2
# 5664      Medium  Supermarket Type2
# 5665      Medium  Supermarket Type3
# 5666       Small  Supermarket Type1
# 5667       Small  Supermarket Type1
# 5668         NaN      Grocery Store
# 5669      Medium  Supermarket Type3
# 5670         NaN  Supermarket Type1
# 5671      Medium  Supermarket Type1
# 5672      Medium  Supermarket Type1
# 5673      Medium  Supermarket Type2
# 5674       Small  Supermarket Type1
# 5675      Medium  Supermarket Type1
# 5676       Small  Supermarket Type1
# 5677      Medium  Supermarket Type2
# 5678         NaN  Supermarket Type1
# 5679         NaN  Supermarket Type1
# 5680         NaN  Supermarket Type1
#
# [6204 rows x 12 columns]

# %%
data_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# 13             FDS46       17.600          Regular         0.047257
# 14             FDF32       16.350          Low Fat         0.068024
# 15             FDP49        9.000          Regular         0.069089
# 16             NCB42       11.800          Low Fat         0.008596
# 17             FDP49        9.000          Regular         0.069196
# 18             DRI11          NaN          Low Fat         0.034238
# 19             FDU02       13.350          Low Fat         0.102492
# 20             FDN22       18.850          Regular         0.138190
# 21             FDW12          NaN          Regular         0.035400
# 22             NCB30       14.600          Low Fat         0.025698
# 23             FDC37          NaN          Low Fat         0.057557
# 24             FDR28       13.850          Regular         0.025896
# 25             NCD06       13.000          Low Fat         0.099887
# 26             FDV10        7.645          Regular         0.066693
# 27             DRJ59       11.650          low fat         0.019356
# 28             FDE51        5.925          Regular         0.161467
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8493           FDP21        7.420          Regular         0.025886
# 8494           NCI54       15.200          Low Fat         0.000000
# 8495           FDE22        9.695          Low Fat         0.029567
# 8496           FDJ57        7.420          Regular         0.021696
# 8497           FDT08       13.650          Low Fat         0.049209
# 8498           NCP54       15.350          Low Fat         0.035293
# 8499           NCK53       11.600          Low Fat         0.037574
# 8500           NCQ42       20.350          Low Fat         0.000000
# 8501           FDW21        5.340          Regular         0.005998
# 8502           NCH43        8.420          Low Fat         0.070712
# 8503           FDQ44       20.500          Low Fat         0.036133
# 8504           NCN18          NaN          Low Fat         0.124111
# 8505           FDB46       10.500          Regular         0.094146
# 8506           DRF37       17.250          Low Fat         0.084676
# 8507           FDN28        5.880          Regular         0.030242
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8510           FDN58       13.800          Regular         0.056862
# 8511           FDF05       17.500          Low Fat         0.026980
# 8512           FDR26       20.700          Low Fat         0.042801
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 6               Snack Foods   57.6588            OUT013
# 7               Snack Foods  107.7622            OUT027
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 10    Fruits and Vegetables   45.5402            OUT049
# 11                    Dairy  144.1102            OUT046
# 12    Fruits and Vegetables  145.4786            OUT049
# 13              Snack Foods  119.6782            OUT046
# 14    Fruits and Vegetables  196.4426            OUT013
# 15                Breakfast   56.3614            OUT046
# 16       Health and Hygiene  115.3492            OUT018
# 17                Breakfast   54.3614            OUT049
# 18              Hard Drinks  113.2834            OUT027
# 19                    Dairy  230.5352            OUT035
# 20              Snack Foods  250.8724            OUT013
# 21             Baking Goods  144.5444            OUT027
# 22                Household  196.5084            OUT035
# 23             Baking Goods  107.6938            OUT019
# 24             Frozen Foods  165.0210            OUT046
# 25                Household   45.9060            OUT017
# 26              Snack Foods   42.3112            OUT035
# 27              Hard Drinks   39.1164            OUT013
# 28                    Dairy   45.5086            OUT010
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8493            Snack Foods  189.1872            OUT017
# 8494              Household  110.4912            OUT017
# 8495            Snack Foods  160.4920            OUT035
# 8496                Seafood  185.3582            OUT017
# 8497  Fruits and Vegetables  150.0050            OUT035
# 8498              Household  124.5730            OUT018
# 8499     Health and Hygiene  100.0042            OUT035
# 8500              Household  125.1678            OUT017
# 8501            Snack Foods  100.4358            OUT017
# 8502              Household  216.4192            OUT045
# 8503  Fruits and Vegetables  120.1756            OUT035
# 8504              Household  111.7544            OUT027
# 8505            Snack Foods  210.8244            OUT018
# 8506            Soft Drinks  263.1910            OUT018
# 8507           Frozen Foods  101.7990            OUT035
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8510            Snack Foods  231.5984            OUT035
# 8511           Frozen Foods  262.5910            OUT018
# 8512                  Dairy  178.3028            OUT013
# 8513                   Meat   99.9042            OUT035
# 8514                 Canned   57.5904            OUT045
# 8515           Baking Goods  157.5288            OUT018
# 8516                 Others   58.7588            OUT018
# 8517           Frozen Foods  178.8318            OUT046
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# 6                          1987        High               Tier 3
# 7                          1985      Medium               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 10                         1999      Medium               Tier 1
# 11                         1997       Small               Tier 1
# 12                         1999      Medium               Tier 1
# 13                         1997       Small               Tier 1
# 14                         1987        High               Tier 3
# 15                         1997       Small               Tier 1
# 16                         2009      Medium               Tier 3
# 17                         1999      Medium               Tier 1
# 18                         1985      Medium               Tier 3
# 19                         2004       Small               Tier 2
# 20                         1987        High               Tier 3
# 21                         1985      Medium               Tier 3
# 22                         2004       Small               Tier 2
# 23                         1985       Small               Tier 1
# 24                         1997       Small               Tier 1
# 25                         2007         NaN               Tier 2
# 26                         2004       Small               Tier 2
# 27                         1987        High               Tier 3
# 28                         1998         NaN               Tier 3
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8493                       2007         NaN               Tier 2
# 8494                       2007         NaN               Tier 2
# 8495                       2004       Small               Tier 2
# 8496                       2007         NaN               Tier 2
# 8497                       2004       Small               Tier 2
# 8498                       2009      Medium               Tier 3
# 8499                       2004       Small               Tier 2
# 8500                       2007         NaN               Tier 2
# 8501                       2007         NaN               Tier 2
# 8502                       2002         NaN               Tier 2
# 8503                       2004       Small               Tier 2
# 8504                       1985      Medium               Tier 3
# 8505                       2009      Medium               Tier 3
# 8506                       2009      Medium               Tier 3
# 8507                       2004       Small               Tier 2
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8510                       2004       Small               Tier 2
# 8511                       2009      Medium               Tier 3
# 8512                       1987        High               Tier 3
# 8513                       2004       Small               Tier 2
# 8514                       2002         NaN               Tier 2
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# 6     Supermarket Type1           343.5528
# 7     Supermarket Type3          4022.7636
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 10    Supermarket Type1          1516.0266
# 11    Supermarket Type1          2187.1530
# 12    Supermarket Type1          1589.2646
# 13    Supermarket Type1          2145.2076
# 14    Supermarket Type1          1977.4260
# 15    Supermarket Type1          1547.3192
# 16    Supermarket Type2          1621.8888
# 17    Supermarket Type1           718.3982
# 18    Supermarket Type3          2303.6680
# 19    Supermarket Type1          2748.4224
# 20    Supermarket Type1          3775.0860
# 21    Supermarket Type3          4064.0432
# 22    Supermarket Type1          1587.2672
# 23        Grocery Store           214.3876
# 24    Supermarket Type1          4078.0250
# 25    Supermarket Type1           838.9080
# 26    Supermarket Type1          1065.2800
# 27    Supermarket Type1           308.9312
# 28        Grocery Store           178.4344
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8493  Supermarket Type1          4727.1800
# 8494  Supermarket Type1          1637.8680
# 8495  Supermarket Type1          4314.3840
# 8496  Supermarket Type1          3715.1640
# 8497  Supermarket Type1          2247.0750
# 8498  Supermarket Type2          1601.2490
# 8499  Supermarket Type1          2976.1260
# 8500  Supermarket Type1          1907.5170
# 8501  Supermarket Type1          1508.0370
# 8502  Supermarket Type1          3020.0688
# 8503  Supermarket Type1          3392.9168
# 8504  Supermarket Type3          4138.6128
# 8505  Supermarket Type2          2117.2440
# 8506  Supermarket Type2          3944.8650
# 8507  Supermarket Type1           515.9950
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8510  Supermarket Type1          7182.6504
# 8511  Supermarket Type2          4207.8560
# 8512  Supermarket Type1          2479.4392
# 8513  Supermarket Type1           595.2252
# 8514  Supermarket Type1           468.7232
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
data_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data_train.columns[data_train.isnull().any()]
# Out:
# Index([u'Item_Weight', u'Outlet_Size'], dtype='object')

# %%
data_test.columns[data_test.isnull().any()]
# Out:
# Index([u'Item_Weight', u'Outlet_Size'], dtype='object')

# %%
all_data.columns[all_data.isnull().any()]
# Out:
# Index([u'Item_Outlet_Sales', u'Item_Weight', u'Outlet_Size'], dtype='object')

# %%
data_train.select_dtypes(exclude=[np.number]).columns
# Out:
# Index([u'Item_Identifier', u'Item_Fat_Content', u'Item_Type',
#        u'Outlet_Identifier', u'Outlet_Size', u'Outlet_Location_Type',
#        u'Outlet_Type'],
#       dtype='object')

# %%
data_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# 13             FDS46       17.600          Regular         0.047257
# 14             FDF32       16.350          Low Fat         0.068024
# 15             FDP49        9.000          Regular         0.069089
# 16             NCB42       11.800          Low Fat         0.008596
# 17             FDP49        9.000          Regular         0.069196
# 18             DRI11          NaN          Low Fat         0.034238
# 19             FDU02       13.350          Low Fat         0.102492
# 20             FDN22       18.850          Regular         0.138190
# 21             FDW12          NaN          Regular         0.035400
# 22             NCB30       14.600          Low Fat         0.025698
# 23             FDC37          NaN          Low Fat         0.057557
# 24             FDR28       13.850          Regular         0.025896
# 25             NCD06       13.000          Low Fat         0.099887
# 26             FDV10        7.645          Regular         0.066693
# 27             DRJ59       11.650          low fat         0.019356
# 28             FDE51        5.925          Regular         0.161467
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8493           FDP21        7.420          Regular         0.025886
# 8494           NCI54       15.200          Low Fat         0.000000
# 8495           FDE22        9.695          Low Fat         0.029567
# 8496           FDJ57        7.420          Regular         0.021696
# 8497           FDT08       13.650          Low Fat         0.049209
# 8498           NCP54       15.350          Low Fat         0.035293
# 8499           NCK53       11.600          Low Fat         0.037574
# 8500           NCQ42       20.350          Low Fat         0.000000
# 8501           FDW21        5.340          Regular         0.005998
# 8502           NCH43        8.420          Low Fat         0.070712
# 8503           FDQ44       20.500          Low Fat         0.036133
# 8504           NCN18          NaN          Low Fat         0.124111
# 8505           FDB46       10.500          Regular         0.094146
# 8506           DRF37       17.250          Low Fat         0.084676
# 8507           FDN28        5.880          Regular         0.030242
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8510           FDN58       13.800          Regular         0.056862
# 8511           FDF05       17.500          Low Fat         0.026980
# 8512           FDR26       20.700          Low Fat         0.042801
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 6               Snack Foods   57.6588            OUT013
# 7               Snack Foods  107.7622            OUT027
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 10    Fruits and Vegetables   45.5402            OUT049
# 11                    Dairy  144.1102            OUT046
# 12    Fruits and Vegetables  145.4786            OUT049
# 13              Snack Foods  119.6782            OUT046
# 14    Fruits and Vegetables  196.4426            OUT013
# 15                Breakfast   56.3614            OUT046
# 16       Health and Hygiene  115.3492            OUT018
# 17                Breakfast   54.3614            OUT049
# 18              Hard Drinks  113.2834            OUT027
# 19                    Dairy  230.5352            OUT035
# 20              Snack Foods  250.8724            OUT013
# 21             Baking Goods  144.5444            OUT027
# 22                Household  196.5084            OUT035
# 23             Baking Goods  107.6938            OUT019
# 24             Frozen Foods  165.0210            OUT046
# 25                Household   45.9060            OUT017
# 26              Snack Foods   42.3112            OUT035
# 27              Hard Drinks   39.1164            OUT013
# 28                    Dairy   45.5086            OUT010
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8493            Snack Foods  189.1872            OUT017
# 8494              Household  110.4912            OUT017
# 8495            Snack Foods  160.4920            OUT035
# 8496                Seafood  185.3582            OUT017
# 8497  Fruits and Vegetables  150.0050            OUT035
# 8498              Household  124.5730            OUT018
# 8499     Health and Hygiene  100.0042            OUT035
# 8500              Household  125.1678            OUT017
# 8501            Snack Foods  100.4358            OUT017
# 8502              Household  216.4192            OUT045
# 8503  Fruits and Vegetables  120.1756            OUT035
# 8504              Household  111.7544            OUT027
# 8505            Snack Foods  210.8244            OUT018
# 8506            Soft Drinks  263.1910            OUT018
# 8507           Frozen Foods  101.7990            OUT035
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8510            Snack Foods  231.5984            OUT035
# 8511           Frozen Foods  262.5910            OUT018
# 8512                  Dairy  178.3028            OUT013
# 8513                   Meat   99.9042            OUT035
# 8514                 Canned   57.5904            OUT045
# 8515           Baking Goods  157.5288            OUT018
# 8516                 Others   58.7588            OUT018
# 8517           Frozen Foods  178.8318            OUT046
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# 6                          1987        High               Tier 3
# 7                          1985      Medium               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 10                         1999      Medium               Tier 1
# 11                         1997       Small               Tier 1
# 12                         1999      Medium               Tier 1
# 13                         1997       Small               Tier 1
# 14                         1987        High               Tier 3
# 15                         1997       Small               Tier 1
# 16                         2009      Medium               Tier 3
# 17                         1999      Medium               Tier 1
# 18                         1985      Medium               Tier 3
# 19                         2004       Small               Tier 2
# 20                         1987        High               Tier 3
# 21                         1985      Medium               Tier 3
# 22                         2004       Small               Tier 2
# 23                         1985       Small               Tier 1
# 24                         1997       Small               Tier 1
# 25                         2007         NaN               Tier 2
# 26                         2004       Small               Tier 2
# 27                         1987        High               Tier 3
# 28                         1998         NaN               Tier 3
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8493                       2007         NaN               Tier 2
# 8494                       2007         NaN               Tier 2
# 8495                       2004       Small               Tier 2
# 8496                       2007         NaN               Tier 2
# 8497                       2004       Small               Tier 2
# 8498                       2009      Medium               Tier 3
# 8499                       2004       Small               Tier 2
# 8500                       2007         NaN               Tier 2
# 8501                       2007         NaN               Tier 2
# 8502                       2002         NaN               Tier 2
# 8503                       2004       Small               Tier 2
# 8504                       1985      Medium               Tier 3
# 8505                       2009      Medium               Tier 3
# 8506                       2009      Medium               Tier 3
# 8507                       2004       Small               Tier 2
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8510                       2004       Small               Tier 2
# 8511                       2009      Medium               Tier 3
# 8512                       1987        High               Tier 3
# 8513                       2004       Small               Tier 2
# 8514                       2002         NaN               Tier 2
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# 6     Supermarket Type1           343.5528
# 7     Supermarket Type3          4022.7636
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 10    Supermarket Type1          1516.0266
# 11    Supermarket Type1          2187.1530
# 12    Supermarket Type1          1589.2646
# 13    Supermarket Type1          2145.2076
# 14    Supermarket Type1          1977.4260
# 15    Supermarket Type1          1547.3192
# 16    Supermarket Type2          1621.8888
# 17    Supermarket Type1           718.3982
# 18    Supermarket Type3          2303.6680
# 19    Supermarket Type1          2748.4224
# 20    Supermarket Type1          3775.0860
# 21    Supermarket Type3          4064.0432
# 22    Supermarket Type1          1587.2672
# 23        Grocery Store           214.3876
# 24    Supermarket Type1          4078.0250
# 25    Supermarket Type1           838.9080
# 26    Supermarket Type1          1065.2800
# 27    Supermarket Type1           308.9312
# 28        Grocery Store           178.4344
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8493  Supermarket Type1          4727.1800
# 8494  Supermarket Type1          1637.8680
# 8495  Supermarket Type1          4314.3840
# 8496  Supermarket Type1          3715.1640
# 8497  Supermarket Type1          2247.0750
# 8498  Supermarket Type2          1601.2490
# 8499  Supermarket Type1          2976.1260
# 8500  Supermarket Type1          1907.5170
# 8501  Supermarket Type1          1508.0370
# 8502  Supermarket Type1          3020.0688
# 8503  Supermarket Type1          3392.9168
# 8504  Supermarket Type3          4138.6128
# 8505  Supermarket Type2          2117.2440
# 8506  Supermarket Type2          3944.8650
# 8507  Supermarket Type1           515.9950
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8510  Supermarket Type1          7182.6504
# 8511  Supermarket Type2          4207.8560
# 8512  Supermarket Type1          2479.4392
# 8513  Supermarket Type1           595.2252
# 8514  Supermarket Type1           468.7232
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
num = [f for f in data_train.columns if data_train.dtypes[f] != 'object']

nd = pd.melt(data_train, value_vars = num)
n1 = sns.FacetGrid (nd, col='variable', col_wrap=4, sharex=False, sharey = False)
n1 = n1.map(sns.distplot, 'value')
n1

# %%
sns.distplot(np.log(data_train[data_train['Item_Visibility']>0]['Item_Visibility']))
# Out:
# /Users/maxim/anaconda3/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-149-655f1eb51c1e> in <module>()
# ----> 1 sns.distplot(np.log(data_train['Item_Visibility']))
#
# /Users/maxim/anaconda3/envs/tensorflow/lib/python2.7/site-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210     if hist:
#     211         if bins is None:
# --> 212             bins = min(_freedman_diaconis_bins(a), 50)
#     213         hist_kws.setdefault("alpha", 0.4)
#     214         hist_kws.setdefault("normed", norm_hist)
#
# /Users/maxim/anaconda3/envs/tensorflow/lib/python2.7/site-packages/seaborn/distributions.pyc in _freedman_diaconis_bins(a)
#      34         return int(np.sqrt(a.size))
#      35     else:
# ---> 36         return int(np.ceil((a.max() - a.min()) / h))
#      37
#      38
#
# OverflowError: cannot convert float infinity to integer

# %%
sns.jointplot(data_train['Item_Outlet_Sales'], data_train['Item_MRP'])

# %%
numeric=data_train.select_dtypes(include=[np.number])
categoric=data_train.select_dtypes(exclude=[np.number])
categoric
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# 5              FDP36          Regular           Baking Goods
# 6              FDO10          Regular            Snack Foods
# 7              FDP10          Low Fat            Snack Foods
# 8              FDH17          Regular           Frozen Foods
# 9              FDU28          Regular           Frozen Foods
# 10             FDY07          Low Fat  Fruits and Vegetables
# 11             FDA03          Regular                  Dairy
# 12             FDX32          Regular  Fruits and Vegetables
# 13             FDS46          Regular            Snack Foods
# 14             FDF32          Low Fat  Fruits and Vegetables
# 15             FDP49          Regular              Breakfast
# 16             NCB42          Low Fat     Health and Hygiene
# 17             FDP49          Regular              Breakfast
# 18             DRI11          Low Fat            Hard Drinks
# 19             FDU02          Low Fat                  Dairy
# 20             FDN22          Regular            Snack Foods
# 21             FDW12          Regular           Baking Goods
# 22             NCB30          Low Fat              Household
# 23             FDC37          Low Fat           Baking Goods
# 24             FDR28          Regular           Frozen Foods
# 25             NCD06          Low Fat              Household
# 26             FDV10          Regular            Snack Foods
# 27             DRJ59          low fat            Hard Drinks
# 28             FDE51          Regular                  Dairy
# 29             FDC14          Regular                 Canned
# ...              ...              ...                    ...
# 8493           FDP21          Regular            Snack Foods
# 8494           NCI54          Low Fat              Household
# 8495           FDE22          Low Fat            Snack Foods
# 8496           FDJ57          Regular                Seafood
# 8497           FDT08          Low Fat  Fruits and Vegetables
# 8498           NCP54          Low Fat              Household
# 8499           NCK53          Low Fat     Health and Hygiene
# 8500           NCQ42          Low Fat              Household
# 8501           FDW21          Regular            Snack Foods
# 8502           NCH43          Low Fat              Household
# 8503           FDQ44          Low Fat  Fruits and Vegetables
# 8504           NCN18          Low Fat              Household
# 8505           FDB46          Regular            Snack Foods
# 8506           DRF37          Low Fat            Soft Drinks
# 8507           FDN28          Regular           Frozen Foods
# 8508           FDW31          Regular  Fruits and Vegetables
# 8509           FDG45          Low Fat  Fruits and Vegetables
# 8510           FDN58          Regular            Snack Foods
# 8511           FDF05          Low Fat           Frozen Foods
# 8512           FDR26          Low Fat                  Dairy
# 8513           FDH31          Regular                   Meat
# 8514           FDA01          Regular                 Canned
# 8515           FDH24          Low Fat           Baking Goods
# 8516           NCJ19          Low Fat                 Others
# 8517           FDF53              reg           Frozen Foods
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# 2               OUT049      Medium               Tier 1  Supermarket Type1
# 3               OUT010         NaN               Tier 3      Grocery Store
# 4               OUT013        High               Tier 3  Supermarket Type1
# 5               OUT018      Medium               Tier 3  Supermarket Type2
# 6               OUT013        High               Tier 3  Supermarket Type1
# 7               OUT027      Medium               Tier 3  Supermarket Type3
# 8               OUT045         NaN               Tier 2  Supermarket Type1
# 9               OUT017         NaN               Tier 2  Supermarket Type1
# 10              OUT049      Medium               Tier 1  Supermarket Type1
# 11              OUT046       Small               Tier 1  Supermarket Type1
# 12              OUT049      Medium               Tier 1  Supermarket Type1
# 13              OUT046       Small               Tier 1  Supermarket Type1
# 14              OUT013        High               Tier 3  Supermarket Type1
# 15              OUT046       Small               Tier 1  Supermarket Type1
# 16              OUT018      Medium               Tier 3  Supermarket Type2
# 17              OUT049      Medium               Tier 1  Supermarket Type1
# 18              OUT027      Medium               Tier 3  Supermarket Type3
# 19              OUT035       Small               Tier 2  Supermarket Type1
# 20              OUT013        High               Tier 3  Supermarket Type1
# 21              OUT027      Medium               Tier 3  Supermarket Type3
# 22              OUT035       Small               Tier 2  Supermarket Type1
# 23              OUT019       Small               Tier 1      Grocery Store
# 24              OUT046       Small               Tier 1  Supermarket Type1
# 25              OUT017         NaN               Tier 2  Supermarket Type1
# 26              OUT035       Small               Tier 2  Supermarket Type1
# 27              OUT013        High               Tier 3  Supermarket Type1
# 28              OUT010         NaN               Tier 3      Grocery Store
# 29              OUT019       Small               Tier 1      Grocery Store
# ...                ...         ...                  ...                ...
# 8493            OUT017         NaN               Tier 2  Supermarket Type1
# 8494            OUT017         NaN               Tier 2  Supermarket Type1
# 8495            OUT035       Small               Tier 2  Supermarket Type1
# 8496            OUT017         NaN               Tier 2  Supermarket Type1
# 8497            OUT035       Small               Tier 2  Supermarket Type1
# 8498            OUT018      Medium               Tier 3  Supermarket Type2
# 8499            OUT035       Small               Tier 2  Supermarket Type1
# 8500            OUT017         NaN               Tier 2  Supermarket Type1
# 8501            OUT017         NaN               Tier 2  Supermarket Type1
# 8502            OUT045         NaN               Tier 2  Supermarket Type1
# 8503            OUT035       Small               Tier 2  Supermarket Type1
# 8504            OUT027      Medium               Tier 3  Supermarket Type3
# 8505            OUT018      Medium               Tier 3  Supermarket Type2
# 8506            OUT018      Medium               Tier 3  Supermarket Type2
# 8507            OUT035       Small               Tier 2  Supermarket Type1
# 8508            OUT045         NaN               Tier 2  Supermarket Type1
# 8509            OUT010         NaN               Tier 3      Grocery Store
# 8510            OUT035       Small               Tier 2  Supermarket Type1
# 8511            OUT018      Medium               Tier 3  Supermarket Type2
# 8512            OUT013        High               Tier 3  Supermarket Type1
# 8513            OUT035       Small               Tier 2  Supermarket Type1
# 8514            OUT045         NaN               Tier 2  Supermarket Type1
# 8515            OUT018      Medium               Tier 3  Supermarket Type2
# 8516            OUT018      Medium               Tier 3  Supermarket Type2
# 8517            OUT046       Small               Tier 1  Supermarket Type1
# 8518            OUT013        High               Tier 3  Supermarket Type1
# 8519            OUT045         NaN               Tier 2  Supermarket Type1
# 8520            OUT035       Small               Tier 2  Supermarket Type1
# 8521            OUT018      Medium               Tier 3  Supermarket Type2
# 8522            OUT046       Small               Tier 1  Supermarket Type1
#
# [8523 rows x 7 columns]

# %%
all_data.columns[all_data.isnull().any()]
# Out:
# Index([u'Item_Outlet_Sales', u'Item_Weight', u'Outlet_Size'], dtype='object')

# %%
correlation=numeric.corr()

# %%
sns.heatmap(correlation, cmap="Blues")

# %%
correlation['Item_Outlet_Sales'].sort_values(ascending=False)
# Out:
# Item_Outlet_Sales            1.000000
# Item_MRP                     0.567574
# Item_Weight                  0.014123
# Outlet_Establishment_Year   -0.049135
# Item_Visibility             -0.128625
# Name: Item_Outlet_Sales, dtype: float64

# %%
cat = [f for f in data_train.columns if data_train.dtypes[f] == 'object']
def anova(frame):
    anv = pd.DataFrame()
    anv['features'] = cat
    pvals = []
    for c in cat:
           samples = []
           for cls in frame[c].unique():
                  s = frame[frame[c] == cls]['Item_outlet_Sales'].values
                  samples.append(s)
           pval = stats.f_oneway(*samples)[1]
           pvals.append(pval)
    anv['pval'] = pvals
    return anv.sort_values('pval')

categoric['Item_outlet_Sales'] = data_train.Item_Outlet_Sales.values
k = anova(categoric) 
k['disparity'] = np.log(1./k['pval'].values) 
sns.barplot(data=k, x = 'features', y='disparity') 
plt.xticks(rotation=90) 
plt
# Out:
# /Users/maxim/anaconda3/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/maxim/anaconda3/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in divide
# <module 'matplotlib.pylab' from '/Users/maxim/anaconda3/envs/tensorflow/lib/python2.7/site-packages/matplotlib/pylab.pyc'>

# %%
data_train.Item_Outlet_Sales.values.shape
# Out:
# (8523,)

# %%
all_data.columns[all_data.isnull().any()]
# Out:
# Index([u'Item_Outlet_Sales', u'Item_Weight', u'Outlet_Size'], dtype='object')

# %%
all_data['Item_Weight'].fillna(all_data['Item_Weight'].mean(), inplace=True)

# %%
all_data['Outlet_Size'].fillna('Medium', inplace=True)

# %%
all_data.describe()
# Out:
#            Item_MRP  Item_Outlet_Sales  Item_Visibility   Item_Weight  \
# count  14204.000000        8523.000000     14204.000000  14204.000000
# mean     141.004977        2181.288914         0.065953     12.792854
# std       62.086938        1706.499616         0.051459      4.234226
# min       31.290000          33.290000         0.000000      4.555000
# 25%       94.012000         834.247400         0.027036      9.300000
# 50%      142.247000        1794.331000         0.054021     12.792854
# 75%      185.855600        3101.296400         0.094037     16.000000
# max      266.888400       13086.964800         0.328391     21.350000
#
#        Outlet_Establishment_Year
# count               14204.000000
# mean                 1997.830681
# std                     8.371664
# min                  1985.000000
# 25%                  1987.000000
# 50%                  1999.000000
# 75%                  2004.000000
# max                  2009.000000

# %%
all_data.columns[all_data.isnull().any()]
# Out:
# Index([u'Item_Outlet_Sales'], dtype='object')

# %%
all_data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
all_data['Item_Fat_Content']=all_data['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'})

# %%
all_data['Item_Identifier']=all_data['Item_Identifier'].apply(lambda x: x[0:2])
all_data['Item_Identifier'].value_counts()
# Out:
# FD    10201
# NC     2686
# DR     1317
# Name: Item_Identifier, dtype: int64

# %%
all_data.loc[all_data['Item_Identifier']=="NC",'Item_Fat_Content'] = "Non-Edible"

# %%
all_data['Item_Identifier'].value_counts()
# Out:
# FD    10201
# NC     2686
# DR     1317
# Name: Item_Identifier, dtype: int64

# %%
all_data.columns[all_data.isnull().any()]
# Out:
# Index([u'Item_Outlet_Sales'], dtype='object')

# %%
sns.countplot(x = 'Outlet_Location_Type', data=data_train)

# %%
sns.countplot(x = 'Outlet_Size', data=data_train)

# %%
g=sns.countplot(x = 'Outlet_Type', data=data_train)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
all_data.loc[all_data['Item_Visibility']==0,'Item_Visibility'] = all_data[all_data['Item_Visibility']>0]['Item_Visibility'].mean()

# %%
all_data['Item_Visibility']
# Out:
# 0       0.016047
# 1       0.019278
# 2       0.016760
# 3       0.070303
# 4       0.070303
# 5       0.070303
# 6       0.012741
# 7       0.127470
# 8       0.016687
# 9       0.094450
# 10      0.070303
# 11      0.045464
# 12      0.100014
# 13      0.047257
# 14      0.068024
# 15      0.069089
# 16      0.008596
# 17      0.069196
# 18      0.034238
# 19      0.102492
# 20      0.138190
# 21      0.035400
# 22      0.025698
# 23      0.057557
# 24      0.025896
# 25      0.099887
# 26      0.066693
# 27      0.019356
# 28      0.161467
# 29      0.072222
#           ...
# 5651    0.048645
# 5652    0.087847
# 5653    0.028977
# 5654    0.070303
# 5655    0.099375
# 5656    0.158425
# 5657    0.035911
# 5658    0.037656
# 5659    0.044073
# 5660    0.026065
# 5661    0.070303
# 5662    0.026234
# 5663    0.033516
# 5664    0.045168
# 5665    0.024110
# 5666    0.014019
# 5667    0.045270
# 5668    0.288892
# 5669    0.072529
# 5670    0.037092
# 5671    0.054463
# 5672    0.036594
# 5673    0.094053
# 5674    0.030704
# 5675    0.070411
# 5676    0.013496
# 5677    0.142991
# 5678    0.073529
# 5679    0.070303
# 5680    0.104720
# Name: Item_Visibility, Length: 14204, dtype: float64

# %%
sns.distplot(all_data['Item_Visibility'])

# %%
sns.distplot(np.log(all_data['Item_Visibility']))

# %%
del all_data['Item_Outlet_Sales']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
def factorize(data, var, fill_na = None):
      if fill_na is not None:
            data[var].fillna(fill_na, inplace=True)
      le.fit(data[var])
      data[var] = le.transform(data[var])
      return data

# %%
all_data.select_dtypes(exclude=[np.number]).columns
# Out:
# Index([u'Item_Fat_Content', u'Item_Identifier', u'Item_Type',
#        u'Outlet_Identifier', u'Outlet_Location_Type', u'Outlet_Size',
#        u'Outlet_Type'],
#       dtype='object')

# %%
all_data['Outlet_Location_Type']=all_data['Outlet_Location_Type'].map({'Tier 1': 3, 'Tier 2': 2, 'Tier 3': 1})

# %%
all_data['Outlet_Type']=all_data['Outlet_Type'].map({'Grocery Store': 1, 'Supermarket Type1': 2, 'Supermarket Type2': 3,'Supermarket Type3': 4})

# %%
all_data['Outlet_Size']=all_data['Outlet_Size'].map({'Small': 1, 'Medium': 2, 'High': 3})

# %%
all_data = factorize(all_data, "Item_Fat_Content")
all_data = factorize(all_data, "Item_Identifier")
all_data = factorize(all_data, "Item_Type")
all_data = factorize(all_data, "Outlet_Identifier")

# %%
all_data
# Out:
#       Item_Fat_Content  Item_Identifier  Item_MRP  Item_Type  Item_Visibility  \
# 0                    1              156  249.8092          4         0.016047
# 1                    2                8   48.2692         14         0.019278
# 2                    1              662  141.6180         10         0.016760
# 3                    2             1121  182.0950          6         0.000000
# 4                    1             1297   53.8614          9         0.000000
# 5                    2              758   51.4008          0         0.000000
# 6                    2              696   57.6588         13         0.012741
# 7                    1              738  107.7622         13         0.127470
# 8                    2              440   96.9726          5         0.016687
# 9                    2              990  187.8214          5         0.094450
# 10                   1             1171   45.5402          6         0.000000
# 11                   2              147  144.1102          4         0.045464
# 12                   2             1142  145.4786          6         0.100014
# 13                   2              904  119.6782         13         0.047257
# 14                   1              375  196.4426          6         0.068024
# 15                   2              767   56.3614          2         0.069089
# 16                   1             1280  115.3492          8         0.008596
# 17                   2              767   54.3614          2         0.069196
# 18                   1               79  113.2834          7         0.034238
# 19                   1              968  230.5352          4         0.102492
# 20                   2              666  250.8724         13         0.138190
# 21                   2             1076  144.5444          0         0.035400
# 22                   1             1278  196.5084          9         0.025698
# 23                   1              259  107.6938          0         0.057557
# 24                   2              843  165.0210          5         0.025896
# 25                   1             1294   45.9060          9         0.099887
# 26                   2             1024   42.3112         13         0.066693
# 27                   3              101   39.1164          7         0.019356
# 28                   2              350   45.5086          4         0.161467
# 29                   2              244   43.6454          3         0.072222
# ...                ...              ...       ...        ...              ...
# 5651                 2              292  186.1898         15         0.048645
# 5652                 1              755  126.7678          6         0.087847
# 5653                 2              711   80.2960          6         0.028977
# 5654                 1              816  144.5760         13         0.000000
# 5655                 2             1142  143.6786          6         0.099375
# 5656                 1              261  207.8296          4         0.158425
# 5657                 1             1011  261.3278          6         0.035911
# 5658                 1              608  123.4704         13         0.037656
# 5659                 1              108  188.8530         14         0.044073
# 5660                 1              554  215.3850         13         0.026065
# 5661                 1               59  155.7972         14         0.000000
# 5662                 1              554  214.3850         13         0.026234
# 5663                 1               71   72.8696         14         0.033516
# 5664                 2               14  173.4054         14         0.045168
# 5665                 1               27   46.0718          4         0.024110
# 5666                 2              377  196.9084         13         0.014019
# 5667                 1             1232   82.1250         13         0.045270
# 5668                 1              264  115.1518          6         0.288892
# 5669                 1              672  188.0530          6         0.072529
# 5670                 2              692  229.4352         10         0.037092
# 5671                 4              145   59.5904          3         0.054463
# 5672                 1             1338  231.1010          9         0.036594
# 5673                 1              385  116.0834         13         0.094053
# 5674                 1              116   43.2770          7         0.030704
# 5675                 2             1104   63.4484         13         0.070411
# 5676                 2              233  141.3154         13         0.013496
# 5677                 2              308  169.1448         15         0.142991
# 5678                 1             1426  118.7440          8         0.073529
# 5679                 2              521  214.6218          3         0.000000
# 5680                 2              997   79.7960          3         0.104720
#
#       Item_Weight  Outlet_Establishment_Year  Outlet_Identifier  \
# 0        9.300000                       1999                  9
# 1        5.920000                       2009                  3
# 2       17.500000                       1999                  9
# 3       19.200000                       1998                  0
# 4        8.930000                       1987                  1
# 5       10.395000                       2009                  3
# 6       13.650000                       1987                  1
# 7       12.792854                       1985                  5
# 8       16.200000                       2002                  7
# 9       19.200000                       2007                  2
# 10      11.800000                       1999                  9
# 11      18.500000                       1997                  8
# 12      15.100000                       1999                  9
# 13      17.600000                       1997                  8
# 14      16.350000                       1987                  1
# 15       9.000000                       1997                  8
# 16      11.800000                       2009                  3
# 17       9.000000                       1999                  9
# 18      12.792854                       1985                  5
# 19      13.350000                       2004                  6
# 20      18.850000                       1987                  1
# 21      12.792854                       1985                  5
# 22      14.600000                       2004                  6
# 23      12.792854                       1985                  4
# 24      13.850000                       1997                  8
# 25      13.000000                       2007                  2
# 26       7.645000                       2004                  6
# 27      11.650000                       1987                  1
# 28       5.925000                       1998                  0
# 29      12.792854                       1985                  4
# ...           ...                        ...                ...
# 5651     9.500000                       1987                  1
# 5652     6.650000                       2002                  7
# 5653     6.760000                       2004                  6
# 5654     7.275000                       1987                  1
# 5655    12.792854                       1985                  5
# 5656    12.792854                       1985                  5
# 5657    16.200000                       1997                  8
# 5658    15.600000                       1987                  1
# 5659     5.000000                       1999                  9
# 5660     9.800000                       1987                  1
# 5661    12.792854                       1985                  5
# 5662     9.800000                       2007                  2
# 5663    16.200000                       2009                  3
# 5664    13.000000                       2009                  3
# 5665    12.792854                       1985                  5
# 5666     9.300000                       1997                  8
# 5667     9.395000                       1997                  8
# 5668    15.600000                       1998                  0
# 5669    12.792854                       1985                  5
# 5670    10.395000                       2007                  2
# 5671    15.000000                       1999                  9
# 5672     6.860000                       1999                  9
# 5673     7.070000                       2009                  3
# 5674    15.700000                       1997                  8
# 5675    13.000000                       1999                  9
# 5676    10.500000                       1997                  8
# 5677     7.600000                       2009                  3
# 5678    10.000000                       2002                  7
# 5679    15.300000                       2007                  2
# 5680     9.500000                       2002                  7
#
#       Outlet_Location_Type  Outlet_Size  Outlet_Type
# 0                        3            2            2
# 1                        1            2            3
# 2                        3            2            2
# 3                        1            2            1
# 4                        1            3            2
# 5                        1            2            3
# 6                        1            3            2
# 7                        1            2            4
# 8                        2            2            2
# 9                        2            2            2
# 10                       3            2            2
# 11                       3            1            2
# 12                       3            2            2
# 13                       3            1            2
# 14                       1            3            2
# 15                       3            1            2
# 16                       1            2            3
# 17                       3            2            2
# 18                       1            2            4
# 19                       2            1            2
# 20                       1            3            2
# 21                       1            2            4
# 22                       2            1            2
# 23                       3            1            1
# 24                       3            1            2
# 25                       2            2            2
# 26                       2            1            2
# 27                       1            3            2
# 28                       1            2            1
# 29                       3            1            1
# ...                    ...          ...          ...
# 5651                     1            3            2
# 5652                     2            2            2
# 5653                     2            1            2
# 5654                     1            3            2
# 5655                     1            2            4
# 5656                     1            2            4
# 5657                     3            1            2
# 5658                     1            3            2
# 5659                     3            2            2
# 5660                     1            3            2
# 5661                     1            2            4
# 5662                     2            2            2
# 5663                     1            2            3
# 5664                     1            2            3
# 5665                     1            2            4
# 5666                     3            1            2
# 5667                     3            1            2
# 5668                     1            2            1
# 5669                     1            2            4
# 5670                     2            2            2
# 5671                     3            2            2
# 5672                     3            2            2
# 5673                     1            2            3
# 5674                     3            1            2
# 5675                     3            2            2
# 5676                     3            1            2
# 5677                     1            2            3
# 5678                     2            2            2
# 5679                     2            2            2
# 5680                     2            2            2
#
# [14204 rows x 11 columns]

# %%
data_train=all_data.iloc[:8523, :]

# %%
data_test=all_data.iloc[8523:, :]

# %%
data_train.shape, data_test.shape
# Out:
# ((8523, 11), (5681, 11))

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.1)
clf.fit(data_train, labels_train)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
ypred=clf.predict(data_test)

# %%
y_pred=pd.DataFrame(ypred)
writer = pd.ExcelWriter('big_mart_sales.xlsx')
y_pred.to_excel(writer,'Sheet1')
writer.save()

# %%
scores = np.array([[1, 2, 3, 6],
                   [2, 4, 5, 6],
                   [3, 8, 7, 6]])

# %%
print(np.sum(scores, axis=0))
# Out:
# [ 6 14 15 18]

# %%
scores/(1.0*np.sum(scores, axis=0))
# Out:
# array([[ 0.16666667,  0.14285714,  0.2       ,  0.33333333],
#        [ 0.33333333,  0.28571429,  0.33333333,  0.33333333],
#        [ 0.5       ,  0.57142857,  0.46666667,  0.33333333]])

# %%
np.exp(scores)/np.sum(np.exp(scores), axis=0)
# Out:
# array([[ 0.09003057,  0.00242826,  0.01587624,  0.33333333],
#        [ 0.24472847,  0.01794253,  0.11731043,  0.33333333],
#        [ 0.66524096,  0.97962921,  0.86681333,  0.33333333]])
